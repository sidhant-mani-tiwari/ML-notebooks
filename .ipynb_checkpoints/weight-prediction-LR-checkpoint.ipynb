# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
#  After we have successfully imported the required libraries and configuration
#  We will import the data set that we will be working on

# %%
df = pd.read_csv('height-weight.csv')
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %% [markdown]
#  I will now use a scatter plot to understand the relationship between height and weight

# %%
plt.scatter(df['Weight'], df['Height'])
plt.xlabel('Weight')
plt.ylabel('Height')
plt.show()

# %%
df.corr()
# Out:
#           Weight    Height
# Weight  1.000000  0.931142
# Height  0.931142  1.000000

# %%
X = df[['Weight']]
#Independent features should be in a data frame
#Mathematically speaking we need to build it like a matrix
Y = df['Height']
np.array(X).shape
# Out:
# (23, 1)

# %%
from sklearn.model_selection import train_test_split

# %%
#Train test split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=42)

# %%
#Lets standardize the training and test data using Z-scoreabs
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
#This is the standardized form with mean = 0 and variance = 1 
X_test
mean_test = X_test.mean()
variance_test = X_test.var()
print(f'Mean: {mean_test}')
print(f'Variance: {variance_test}')
# Out:
# Mean: 0.3147783487965052
# Variance: 1.391720706839821

# %% [markdown]
# Now we will apply simple linear regression

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()

# %%
regression.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(X_train, Y_train)
plt.plot(X_train, regression.predict(X_train))
plt.show()
intercept = regression.intercept_
slope = regression.coef_
print(f'Intercept: {intercept} & Slope: {slope}')
# Out:
# Intercept: 156.47058823529412 & Slope: [17.2982057]

# %% [markdown]
# Now we will generate our predicted values

# %% [markdown]
# # Linear regression value of coefficient
# Intercept: 156.47058823529412 & Slope: [17.2982057]
# y_predicted = 156.47058823529412 + 17.2982057*X_test

# %%
y_predicted = regression.predict(X_test)
y_predicted
# Out:
# array([162.26499721, 162.26499721, 127.68347133, 180.07972266,
#        148.64197186, 190.55897293])

# %% [markdown]
# Now lets check the performance metrics

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
mse = mean_squared_error(Y_test, y_predicted)
mae = mean_absolute_error(Y_test, y_predicted)
rmse = np.sqrt(mse)
print(f'Mean squared error(MSE): {mse}')
print(f'Mean absolute error(MAE): {mae}')
print(f'Root mean squared error(RMSE): {rmse}')
# Out:
# Mean squared error(MSE): 114.84069295228699
# Mean absolute error(MAE): 9.665125886795005
# Root mean squared error(RMSE): 10.716374991212605

# %% [markdown]
# Lets check the R square value:
# R^2 = 1 - (RSS/TSS)

# %%
from sklearn.metrics import r2_score

# %%
score = r2_score(Y_test, y_predicted)
print(f'R square score: {score * 100}%')
# Out:
# R square score: 73.60826717981276%

# %% [markdown]
# # Adjusted R^2
# ### adjusted R2 = 1 - [(1-R2)*(N - 1)/(N - K - 1)]
# N : number of observations, K : number of independent variables

# %%
adjusted_r2 = 1 - ((1-score)*(len(Y_test) - 1)/(len(Y_test) - X_test.shape[1] - 1))
print(f'Adjusted R2 score: {adjusted_r2  * 100}%')
# Out:
# Adjusted R2 score: 67.01033397476594%

# %%
new_data = pd.DataFrame({
    'Weight': [56, 100, 74]
})
regression.predict(scaler.transform(new_data))
# Out:
# array([139.21064662, 185.31934779, 158.0732971 ])

# %% [markdown]
# ## Assumptions to see whether our model is really performing well
# ### 1. y test vs. y predicted (The Accuracy Check)
# This plot shows how close your predictions are to the actual truth.
#
# The Goal: You want to see a tight, linear diagonal line (y=x). If every prediction was perfect, all points would sit exactly on a 45-degree line.
#
# The Cases:
#
# *1. Tight Diagonal*: Great! Your model has captured the relationship well.
#
# *2. Wide Cloud*: Your model is weak. It’s "guessing" in the right direction, but with high error (low R2).
#
# *3. Curved Shape*: Your model is trying to fit a straight line to data that is actually curved. You might need a non-linear model.

# %%
plt.scatter(Y_test, y_predicted)
plt.show()

# %%
residuals = Y_test - y_predicted
residuals
# Out:
# 15    14.735003
# 9      7.735003
# 0     -7.683471
# 8      1.920277
# 17    10.358028
# 12   -15.558973
# Name: Height, dtype: float64

# %% [markdown]
# ### 2. Distribution of Residuals (The Error Check)
# A residual is simply the "leftover" error: Residual=y actual−y predicted
#
# The Goal: A Normal Distribution (Bell Curve) centered at zero.
#
# Why it matters: If the errors are normally distributed, it means your model is "wrong" only by random chance.
#
# The Cases:
#
# *1. Bell Curve at Zero*: Perfect. The errors are truly random.
#
# *2. Skewed (Leaning Left/Right)*: Your model is systematically over-predicting or under-predicting certain ranges.
#
# *3. Bimodal (Two bumps)*: You might be missing a major category or variable in your data that splits the results.

# %%
import seaborn as sns
sns.histplot(residuals, kde=True)
plt.show()

# %% [markdown]
# ### y predicted vs. Residuals (The Homoscedasticity Check)
# This is a fancy way of checking if your model’s "guessing ability" is consistent across all values.
#
# The Goal: A "Uniform Cloud" or a random horizontal band. You shouldn't see any discernable shape.
#
# The Cases:
#
# *1. The "Funnel" Shape:* This is called Heteroscedasticity. It means your model is good at predicting small values but gets wildly inaccurate as the values get larger. (Common in income data—it's easier to predict the spending of someone making 30k than someone making 3M).
#
# *2. The "U" or "S" Shape:* This means there is a pattern in the data that your linear model completely missed. You’ve left "information" in the errors.

# %%
plt.scatter(y_predicted, residuals)
plt.show()
